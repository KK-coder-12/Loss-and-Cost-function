# %%
import numpy as np
y_predicted=np.array([1,1,0,0,1])
y_true= np.array([0.30,0.7,1,0,0.5])

# %%
def mae(y_true, y_predicted):
    total_error=0
    for yt,yp in zip(y_true, y_predicted):
        total_error+= abs(yt - yp)
    print("Total Error:",total_error)
    mae= total_error/len(y_true)
    print("MAE:",mae)
    return mae

# %%
mae(y_true, y_predicted)
# Out:
# Total Error: 2.5
# MAE: 0.5
# np.float64(0.5)

# %%
np.mean(np.abs(y_true - y_predicted))
# Out:
# np.float64(0.5)

# %%
absolute_errors = np.abs(y_true - y_predicted)
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))
plt.plot(range(len(y_true)), absolute_errors, marker='o', linestyle='-', color='crimson', label='Absolute Error')

plt.title("Mean Absolute Error (MAE) per Sample", fontsize=14)
plt.xlabel("Sample Index", fontsize=12)
plt.ylabel("Absolute Error", fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
def mse(y_true, y_predicted):
    total_error=0
    for yt,yp in zip(y_true,y_predicted):
        total_error+=(yt - yp)**2
    print("Total_Error:",total_error)
    mse=total_error/len(y_true)
    print("MSE:",mse)
    return mse

# %%
mse(y_true, y_predicted)
# Out:
# Total_Error: 1.83
# MSE: 0.366
# np.float64(0.366)

# %%
np.mean((y_true - y_predicted)**2)
# Out:
# np.float64(0.366)

# %%
y_true = 1
y_pred = np.linspace(0, 2, 100)

mse_loss = (y_true - y_pred) ** 2

plt.figure(figsize=(5, 5))
plt.plot(y_pred, mse_loss, color='blue')
plt.axvline(x=y_true, color='red', linestyle=':', linewidth=1)
plt.axhline(y=0, color='red', linestyle=':', linewidth=1)

plt.title("MSE Loss (U-shaped Parabola)")
plt.xlabel("Predicted Value")
plt.ylabel("MSE Loss")
plt.grid(True, linestyle='--', alpha=0.4)
plt.show()

# %%
eplison =1e-15

# %%
y_predicted_new= [max(i,eplison) for i in y_predicted]
y_predicted_new
# Out:
# [np.int64(1), np.int64(1), 1e-15, 1e-15, np.int64(1)]

# %%
y_predicted_new = [min(i,1-eplison) for i in y_predicted_new]
y_predicted_new
# Out:
# [0.999999999999999, 0.999999999999999, 1e-15, 1e-15, 0.999999999999999]

# %%
y_predicted_new =np.array(y_predicted_new)
np.log(y_predicted_new)
# Out:
# array([-9.99200722e-16, -9.99200722e-16, -3.45387764e+01, -3.45387764e+01,
#        -9.99200722e-16])

# %%
-np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(1-y_predicted_new))
# Out:
# np.float64(17.2696280766844)

# %%
def log_loss(y_true , y_predicted):
    y_predicted_new=[max(i,eplison) for i in y_predicted]
    y_predicted_new=[min(i, 1-eplison) for i in y_predicted_new]
    y_predicted_new= np.array(y_predicted_new)
    return -np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(1-y_predicted_new))

# %%
log_loss(y_true, y_predicted)
# Out:
# np.float64(17.2696280766844)

# %%
y_pred = np.linspace(0.001, 0.999, 100)
y_true_1 = 1  # True label is 1
y_true_0 = 0  # True label is 0

# Calculate log loss for both classes
log_loss_1 = -np.log(y_pred)          # When true label is 1
log_loss_0 = -np.log(1 - y_pred)      # When true label is 0

# Plotting
plt.figure(figsize=(8, 5))
plt.plot(y_pred, log_loss_1, label='Log Loss (y_true = 1)', color='blue', linewidth=2)
plt.plot(y_pred, log_loss_0, label='Log Loss (y_true = 0)', color='red', linewidth=2)
plt.axvline(x=0.5, color='green', linestyle='--', label='Threshold = 0.5')
plt.title("Smooth Log Loss Curve", fontsize=14)
plt.xlabel("Predicted Probability", fontsize=12)
plt.ylabel("Log Loss", fontsize=12)
plt.legend()
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()
